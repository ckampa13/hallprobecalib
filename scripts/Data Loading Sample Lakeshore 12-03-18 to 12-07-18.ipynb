# %%
from hallprobecalib import hpc_ext_path
from hallprobecalib.hallrawdataframe import HallRawDataFrame

# %%
# thursday 12/06/18 121x121, 3deg resolution
#df,meta = HallRawDataFrame('datafiles/2018-12-03 152047',makepickle=True)
#df,meta = HallRawDataFrame('datafiles/2018-12-03 153304',makepickle=True)
#df,meta = HallRawDataFrame('datafiles/2018-12-04 190642',makepickle=True)
#df,meta = HallRawDataFrame('datafiles/2018-12-06 172741',makepickle=True)
#df,meta = HallRawDataFrame('datafiles/2018-12-07 145759',makepickle=True)

# %%
f1 = 'datafiles/2018-12-03 152047'
f2 = 'datafiles/2018-12-03 153304'
f3 = 'datafiles/2018-12-04 190642'
f4 = 'datafiles/2018-12-06 172741'
f5 = 'datafiles/2018-12-06 061040'
f6 = 'datafiles/2018-12-07 145759'

# %%
df1,meta1 = HallRawDataFrame(f1,frompickle=True)
df2,meta2 = HallRawDataFrame(f2,frompickle=True)
df3,meta3 = HallRawDataFrame(f3,frompickle=True)
df4,meta4 = HallRawDataFrame(f4,frompickle=True)
df5,meta5 = HallRawDataFrame(f5,frompickle=True)
df6,meta6 = HallRawDataFrame(f6,frompickle=True)

# %%
print("1 :",df1.columns)
print("2 :",df2.columns)
print("3 :",df3.columns)
print("4 :",df4.columns)
print("5 :",df5.columns)
print("6 :",df6.columns)
# Out:
# 1 : Index(['DATETIME', 'LakeShore_Field Precision', 'LakeShore_Field Unit',
#        'LakeShore_Field V', 'LakeShore_Field X', 'LakeShore_Field Y',
#        'LakeShore_Field Z', 'SmarAct_Meas_Coord', 'SmarAct_Pattern_Coord',
#        'AX0_DEG', 'AX1_DEG', 'AX0_PAT', 'AX1_PAT', 'BX_RAW', 'BY_RAW',
#        'BZ_RAW', 'B_MAG_RAW', 'BX_CAL', 'BY_CAL', 'BZ_CAL', 'B_MAG_CAL',
#        'TEMP', 'NMR_B_AVG', 'FFT_MAX'],
#       dtype='object')
# 2 : Index(['DATETIME', 'LakeShore_Field Precision', 'LakeShore_Field Unit',
#        'LakeShore_Field V', 'LakeShore_Field X', 'LakeShore_Field Y',
#        'LakeShore_Field Z', 'SmarAct_Meas_Coord', 'SmarAct_Pattern_Coord',
#        'AX0_DEG', 'AX1_DEG', 'AX0_PAT', 'AX1_PAT', 'BX_RAW', 'BY_RAW',
#        'BZ_RAW', 'B_MAG_RAW', 'BX_CAL', 'BY_CAL', 'BZ_CAL', 'B_MAG_CAL',
#        'TEMP', 'NMR_B_AVG', 'FFT_MAX'],
#       dtype='object')
# 3 : Index(['DATETIME', 'LakeShore_Field Precision', 'LakeShore_Field Unit',
# ...

# %%
len(df5)
# Out:
# 20

# %%
df5.describe()
# Out:
#           AX0_DEG     AX1_DEG       AX0_PAT    AX1_PAT     NMR_B_AVG  \
# count   20.000000   20.000000  2.000000e+01  20.000000  2.000000e+01
# mean   215.899997  359.499999 -5.000000e-07   0.000000  4.978635e-01
# std    180.675027    0.000003  3.274328e-01   0.512989  1.008194e-08
# min      0.055553  359.499990 -5.000000e-01  -0.500000  4.978635e-01
# 25%      0.277775  359.499998 -2.777780e-01  -0.500000  4.978635e-01
# 50%    359.499999  359.500000 -5.000000e-07   0.000000  4.978635e-01
# 75%    359.722218  359.500000  2.777770e-01   0.500000  4.978635e-01
# max    359.944448  359.500001  4.999990e-01   0.500000  4.978635e-01
#
#          FFT_MAX
# count  20.000000
# mean    4.415085
# std     1.220034
# min     2.067003
# 25%     3.793350
# 50%     4.594220
# 75%     5.235737
# max     6.043716

# %%
df5.head()
# Out:
#            DATETIME                    SmarAct_Meas_Coord  \
# 0  [126201861055.0]       [359.499996, -1.0, 359.5, -1.0]
# 1  [126201861104.0]       [359.499991, -1.0, 359.5, -1.0]
# 2  [126201861114.0]  [359.500001, -1.0, 359.500001, -1.0]
# 3  [126201861123.0]  [359.500002, -1.0, 359.499998, -1.0]
# 4  [126201861133.0]   [359.61111, -1.0, 359.499996, -1.0]
#
#   SmarAct_Pattern_Coord     AX0_DEG     AX1_DEG   AX0_PAT  AX1_PAT  \
# 0          [-0.5, -0.5]  359.499996  359.500000 -0.500000     -0.5
# 1           [-0.5, 0.5]  359.499991  359.500000 -0.500000      0.5
# 2     [-0.388889, -0.5]  359.500001  359.500001 -0.388889     -0.5
# 3      [-0.388889, 0.5]  359.500002  359.499998 -0.388889      0.5
# 4     [-0.277778, -0.5]  359.611110  359.499996 -0.277778     -0.5
#
#                                               BX_RAW  \
# 0  [191952.0, 218543.0, 177420.0, 192790.0, 21685...
# 1  [191918.0, 218598.0, 177365.0, 192725.0, 21677...
# ...

# %%
df5.DATETIME.max()-df5.DATETIME.min()
# Out:
# array([302.])

# %%
302/60
# Out:
# 5.033333333333333
